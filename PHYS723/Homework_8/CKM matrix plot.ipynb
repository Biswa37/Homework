# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import matplotlib.pyplot as plt

#http://pdg.lbl.gov/2015/reviews/rpp2015-rev-ckm-matrix.pdf
#http://ckmfitter.in2p3.fr

# %%
Vckm = np.matrix([[0.97427,0.22536,0.00355],[0.22522,0.97343,0.0414],[0.00886,0.0405,0.99914]])
Vckm_error = np.matrix([[0.00014,0.00061,0.00015],[0.00061,0.00015,0.0012],[0.00033,0.0012,0.00005]])

print Vckm
print Vckm_error
# Out:
# [[ 0.97427  0.22536  0.00355]
#  [ 0.22522  0.97343  0.0414 ]
#  [ 0.00886  0.0405   0.99914]]
# [[  1.40000000e-04   6.10000000e-04   1.50000000e-04]
#  [  6.10000000e-04   1.50000000e-04   1.20000000e-03]
#  [  3.30000000e-04   1.20000000e-03   5.00000000e-05]]

# %%
rho = 0.124
rho_error = 0.024
nu = 0.354
nu_error = 0.015

xs = [0,1,rho,0]
ys = [0,0,nu,0]
xerr = [0,0,rho_error,0]
yerr = [0,0,nu_error,0]

plt.figure(figsize=(10,10))
plt.ylim([-0.1,0.45])
plt.xlim([-0.1,1.1])
plt.errorbar(xs,ys,xerr=xerr, yerr=yerr,fmt='o-',lw=2)

plt.show()

# %%
t = np.linspace(0, 10, 1000, endpoint=True)
X = np.sin(t)
Y = np.cos(t)
plt.figure(figsize=(10,10))
plt.plot(X,Y,c='r',lw=2)
plt.show()

# %%
np.arcsin(0.682-0.019)/2.0
# Out:
# 0.3624095311198024
