# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
from pandas.tools.plotting import scatter_matrix

data = pd.DataFrame.from_csv('truth.csv')

data = pd.DataFrame.convert_objects(data,convert_numeric=True)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:8: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
data.describe()
# Out:
#              event             ID       mother    duaghter1    duaghter2  \
# count  5309.000000    5309.000000  5306.000000  5301.000000  5301.000000
# mean     13.704652   12607.033340     8.567094    19.688927    20.712696
# std       8.976849   66412.287669     8.050109    17.480469    17.862448
# min       0.000000  -30313.000000    -1.000000    -1.000000    -1.000000
# 25%       6.000000    -211.000000     2.000000     3.000000     4.000000
# 50%      13.000000     111.000000     7.000000    18.000000    19.000000
# 75%      20.000000     311.000000    13.000000    33.000000    34.000000
# max      46.000000  900022.000000    42.000000    80.000000    81.000000
#
#                 Px          Py           Pz            E            X  \
# count  5301.000000  5301.00000  5301.000000  5301.000000  5309.000000
# mean      0.017889    -0.00747     0.719910     1.845384     0.488970
# std       0.590421     0.60706     1.146799     2.425642     0.099744
# min      -2.418900    -2.54610    -1.506400     0.003100    -0.009500
# 25%      -0.200000    -0.22330     0.013700     0.338500     0.429400
# 50%       0.008800     0.00000     0.279000     0.999300     0.490400
# 75%       0.226000     0.20570     1.120000     2.246100     0.549900
# max       2.446200     2.48100     4.511100    11.506500     1.231800
#
#                  Y            Z            T    i1    i2           i3
# count  5301.000000  5301.000000  5301.000000  5301  5301  5301.000000
# mean      0.072233    -0.181437     0.484752    55     0    99.979438
# std       0.062786     2.990181     0.716166     0     0    57.138096
# min      -0.815300    -9.404500    -1.560200    55     0     1.000000
# 25%       0.058600    -2.119600     0.043200    55     0    51.000000
# 50%       0.072000    -0.078300     0.426500    55     0   101.000000
# 75%       0.081800     1.958900     0.907200    55     0   149.000000
# max       0.572200     7.882300     4.209200    55     0   199.000000

# %%
#ax = scatter_matrix(data, alpha=0.2, figsize=(16, 9))
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:2767: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=55.0, right=55.0
#   'left=%s, right=%s') % (left, right))
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:2767: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:3025: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=55.0, top=55.0
#   'bottom=%s, top=%s') % (bottom, top))
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:3025: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=0.0, top=0.0
#   'bottom=%s, top=%s') % (bottom, top))

# %%
kinematics = pd.DataFrame()
kinematics['Px'] = data.Px
kinematics['Py'] = data.Py
kinematics['Pz'] = data.Pz
kinematics['E'] = data.E
kinematics['X'] = data.X
kinematics['Y'] = data.Y
kinematics['Z'] = data.Z
kinematics['T'] = data['T']

# %%
kinematics.head()
# Out:
#           Px      Py      Pz        E       X       Y       Z       T
# part
# 1     0.1760  0.0000  4.4988  11.5028  0.3619  0.0787 -1.3131 -0.2107
# 2     0.4054 -0.1093  2.4376   5.8299  0.3619  0.0787 -1.3131 -0.2107
# 3    -0.2294  0.1093  2.0612   5.6729  0.3619  0.0787 -1.3131 -0.2107
# 4     2.0084 -1.4483  1.7238   3.1843  0.4060  0.0668 -1.0481  0.4233
# 5    -1.6030  1.3390  0.7138   2.6456  0.4060  0.0668 -1.0481  0.4233

# %%
ax = scatter_matrix(kinematics, alpha=0.2, figsize=(20, 15))
